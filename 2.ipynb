# %%
import pandas as pd
df=pd.read_csv('1055.csv')
# 按 category 排序，保证相同的连在一起
# 按 category 排序，保证相同的连在一起
df_sorted = df.sort_values(by="category").reset_index(drop=True)

# %%
df_sorted
# Out:
#     category                                           question  \
# 0      event  How many years of Carnegie Mellon University d...
# 1      event  Where will the 'Connecting to Nature Experient...
# 2      event  Which hotels are offering special room rates f...
# 3      event  What event at Mr Small's Fun House starts at 8...
# 4      event  Which event takes place at PPG Paints Arena on...
# ..       ...                                                ...
# 146    sport            Where is The Patio located at PNC Park?
# 147    sport  Which Pittsburgh sports team has won six Super...
# 148    sport  Where do the Pittsburgh Pirates play their hom...
# 149    sport  What is the name of the Pittsburgh Steelers' m...
# 150    sport  Where was the screening of 'Beyond Their Years...
#
#                                       reference_answer  \
# 0                                            125 years
# 1                Well-being Lab in the Highmark Center
# ...

# %%
df_sorted.to_csv('1056.csv',index=False)

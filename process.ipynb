# %%
import pandas as pd
df=pd.read_csv("/Users/racheleven/Desktop/graduate_courses/11-711/anlp-fall2025-hw2/0016.csv")

# %%
df
# Out:
#     category                                           question  \
# 0      event  How many years of Carnegie Mellon University d...
# 1      event  Which organization provides dogs for the Paws ...
# 2      event  Where is the event 'The Art and Science of Raf...
# 3      event  What is the name of the event celebrating 125 ...
# 4      event  Who is the subject of the exhibition at the Hu...
# ..       ...                                                ...
# 96     sport  Who won the Pittsburgh Steelers team MVP award...
# 97     sport  Who serves as the pitching coach for the Pitts...
# 98     sport      Who is the manager of the Pittsburgh Pirates?
# 99     sport                 Where is PPG Paints Arena located?
# 100    sport  What is the name of the Pittsburgh Steelers' m...
#
#                                       reference_answer  \
# 0                                            125 years
# 1                     Animal Friend’s Therapet program
# ...

# %%
list1=[
  {
    "category":"food",
    "question": "What is the address of the Pittsburgh Taco Festival venue?",
    "reference_answer": "2875 Railroad St, Pittsburgh, PA 15222",
    "support_context_segment": "2875 Railroad St, Pittsburgh, PA 15222"
  },
  {
    "category":"food",
    "question": "When did Pittsburgh Restaurant Week start?",
    "reference_answer": "It started in 2012.",
    "support_context_segment": "Pittsburgh Restaurant Week is a celebration of restaurants and dining in the steel city. Started in 2012, it’s been an annual tradition to host a winter edition in January and summer edition in August."
  },
  {
    "category":"food",
    "question": "What is the pricing theme for Pittsburgh Restaurant Week in 2025?",
    "reference_answer": "The pricing theme is '25-cents' for 2025.",
    "support_context_segment": "With such a wide variety of establishments participating, a one-size-fits all pricing model doesn’t make sense, so Pittsburgh Restaurant Week has themed pricing of “25-cents” for 2025."
  },
  {
    "category":"food",
    "question": "When is the 5k Banana Run scheduled?",
    "reference_answer": "Saturday, August 22, 2025",
    "support_context_segment": "Saturday, August 22, 2025\nRegistration at 7am, Kickoff at 9am\nLatrobe Memorial Stadium"
  },
  {
        "category":"food",
    "question": "Where does the 5k Banana Run start and finish?",
    "reference_answer": "Memorial Drive to Stadium Track",
    "support_context_segment": "↑ START – Memorial Dr\n...\n↑ STRAIGHT – onto the TRACK to the FINISH"
  },
  {    "category":"food",
    "question": "Who is the 2025 Presenting Partner for the Pickle Riding event at Picklesburgh?",
    "reference_answer": "Pella Windows & Doors",
    "support_context_segment": "2025 Presenting Partner – Pickle Riding\n\nPella Windows & Doors are rated #1 by homeowners in Pittsburgh as a window brand that pays attention to detail. www.pella.com/pittsburgh"
  },
  {    "category":"food",
    "question": "Which company is listed as the 2025 Band Sponsor for Picklesburgh?",
    "reference_answer": "The PA Lottery",
    "support_context_segment": "2025 Band Sponsor\n\nThe PA Lottery supports programs all around Pennsylvania that benefit older Pennsylvanians. https://www.palottery.pa.gov/"
  },
  {    "category":"food",
    "question": "What is the cost to participate in the pickle-themed carnival games at Li’l Gherkins KidsPlay?",
    "reference_answer": "$2 per play",
    "support_context_segment": "The pickle themed carnival games are $2 per play. Carnival game tickets can be purchased onsite- no reservation necessary."
  },
  {    "category":"food",
    "question": "What are the different admission options and their prices for The Original Pittsburgh Taco Festival?",
    "reference_answer": [
      "General Admission - $17.20",
      "Festival Fan Silver Package - $32.62",
      "Taco Lover’s Gold Package - $53.47"
    ],
    "support_context_segment": "Admission\nGeneral Admission - $17.20\nFestival Fan Silver Package - $32.62\nTaco Lover’s Gold Package - $53.47\nExclusive features of the event will vary depending on the type of admission."
  },
 {    "category":"food",
    "question": "Which benefits do sponsors receive as part of Pittsburgh Restaurant Week? (Select all that apply)",
    "reference_answer": [
      "Logo and link in sponsors section of the Pittsburgh Restaurant Week Official Website",
      "Name placement on all Pittsburgh Restaurant Week promotional posters",
      "Two tickets to a PRW event",
      "Banner signage at the Kickoff Party, Blogger Dinner, Wrap-Party or other special events",
      "Mentions on Social Media pages",
      "Spotlights in e-mail newsletter promoting a service, product, or exclusive deal",
      "Banner ads on high-traffic pages on www.pittsburghrestaurantweek.com"
    ],
    "support_context_segment": "Sponsorship offers a range of program benefits including:\n\n- Logo and link in sponsors section of the Pittsburgh Restaurant Week Official Website\n- Name placement on all Pittsburgh Restaurant Week promotional posters\n- Two tickets to a PRW event.\n- Banner signage at the Kickoff Party, Blogger Dinner, - Wrap-Party or other special events held for Pittsburgh Restaurant Week\n- Mentions on Social Media pages:\nFacebook – www.facebook.com/PghRestaurantWk\nTwitter – www.twitter.com/PghRestaurantWk\n- Spotlights in e-mail newsletter promoting a service, product, or exclusive deal to all participant contacts.\n- Banner ads on high-traffic pages on www.pittsburghrestaurantweek.com"
  }
]

# %%
df1=pd.DataFrame(list1)

# %%
# 合并两个 DataFrame
df_combined = pd.concat([df, df1], ignore_index=True)

# 查看合并后的结果
print(df_combined)
# Out:
#     category                                           question  \
# 0      event  How many years of Carnegie Mellon University d...
# 1      event  Which organization provides dogs for the Paws ...
# 2      event  Where is the event 'The Art and Science of Raf...
# 3      event  What is the name of the event celebrating 125 ...
# 4      event  Who is the subject of the exhibition at the Hu...
# ..       ...                                                ...
# 106     food  Who is the 2025 Presenting Partner for the Pic...
# 107     food  Which company is listed as the 2025 Band Spons...
# 108     food  What is the cost to participate in the pickle-...
# 109     food  What are the different admission options and t...
# 110     food  Which benefits do sponsors receive as part of ...
#
#                                       reference_answer  \
# 0                                            125 years
# 1                     Animal Friend’s Therapet program
# ...

# %%
list2=[
  {
     "category":"event",
    "question": "Which annual edition of CMU's Food Drive is being held in 2025?",
    "reference_answer": "32nd Annual Food Drive",
    "support_context_segment": "CMU’s 32nd Annual Food Drive Oct. 1-Nov. 7, 2025 benefitting the Greater Pittsburgh Community Food Bank"
  },
  {
     "category":"event",
    "question": "When is Carnegie Mellon University's Homecoming Weekend celebrating CMU's 125th anniversary?",
    "reference_answer": "November 6-8",
    "support_context_segment": "Make plans to attend Homecoming Weekend, Nov. 6-8, to celebrate 125 years of Carnegie Mellon University."
  },
  { "category":"event",
    "question": "What is the DSAC at Carnegie Mellon University?",
    "reference_answer": "A student-led organization composed of undergraduate and graduate students dedicated to enhancing the Carnegie Mellon University Dining Services program.",
    "support_context_segment": "The Dining Student Advisory Committee (DSAC) is a student-led organization composed of undergraduate and graduate students dedicated to enhancing the Carnegie Mellon University Dining Services program."
  },
  { "category":"event",
    "question": "When are final grades due?",
    "reference_answer": "December 17 at 4pm",
    "support_context_segment": "Final Grade Due at 4pm\n12.17"
  },
  { "category":"event",
    "question": "What is the purpose of the 'Rare Books & Ancestral Machines' exhibition at the Posner Center?",
    "reference_answer": "It inaugurates University Libraries’ newly renovated Posner Center, surveying its collections and tracing more than four centuries of scientific inquiry and learning.",
    "support_context_segment": "This exhibition inaugurates University Libraries’ newly renovated Posner Center, surveying its collections and tracing more than four centuries of scientific inquiry and learning."
  },
  { "category":"event",
    "question": "Where and when is the 'Start Making Sense - Talking Heads Tribute' concert?",
    "reference_answer": "November 1, 2025 at 8:00 PM, Mr Small's Theatre",
    "support_context_segment": "### [Event Name]: Start Making Sense - Talking Heads Tribute\n**Date & Time:** Nov 1, 2025 8:00 PM\n**Location:** Mr Small's Theatre"
  },
  { "category":"event",
    "question": "Which event takes place at PPG Paints Arena on November 2, 2025?",
    "reference_answer": "Bryan Adams concert at 7:30 PM",
    "support_context_segment": "### [Event Name]: Bryan Adams\n**Date & Time:** Nov 2, 2025 7:30 PM\n**Location:** PPG Paints Arena"
  },
  { "category":"event",
    "question": "What event at Mr Small's Fun House starts at 8:00 PM on October 30, 2025?",
    "reference_answer": "The Local Honeys",
    "support_context_segment": "### [Event Name]: The Local Honeys\n**Date & Time:** Oct 30, 2025 8:00 PM\n**Location:** Mr Small's Fun House"
  },
  { "category":"event",
    "question": "Which hotels are offering special room rates for CMU Homecoming Weekend, and what are their respective booking deadlines?",
    "reference_answer": [
      "Courtyard Pittsburgh University Center - Book by March 9, 2026",
      "Hilton Garden Inn Pittsburgh University Place - Book by March 9, 2026",
      "Residence Inn Pittsburgh Oakland/University Place - Book by March 9, 2026",
      "Hotel Indigo Pittsburgh East Liberty - Book by March 10, 2026",
      "SpringHill Suites Pittsburgh Bakery Square - Book by March 9, 2026",
      "Hotel Indigo Pittsburgh University - Oakland - Book by March 10, 2026"
    ],
    "support_context_segment": "Several local hotels have blocks of rooms held for reunion alumni. Hotels book quickly, so make your reservation as early as possible! The special room rate will be available until varying cut-off dates or until the group block is sold out, whichever comes first.\n\n#### Courtyard Pittsburgh University Center\n- Book by: March 9, 2026  \n\n#### Hilton Garden Inn Pittsburgh University Place\n- Book by: March 9, 2026  \n\n####  Residence Inn Pittsburgh Oakland/University Place\n- Book by: March 9, 2026  \n\n#### Hotel Indigo Pittsburgh East Liberty\n- Book by: March 10, 2026  \n\n#### SpringHill Suites Pittsburgh Bakery Square\n- Book by: March 9, 2026  \n\n#### Hotel Indigo Pittsburgh University - Oakland\n- Book by: March 10, 2026"
  },
  { "category":"event",
    "question": "Where will the 'Connecting to Nature Experiential Workshop' meet before walking to Schenley Park?",
    "reference_answer": "Well-being Lab in the Highmark Center",
    "support_context_segment": "We will meet in the Well-being Lab in the Highmark Center and walk to Schenley Park, weather permitting."
  }
]

# %%
df2=pd.DataFrame(list2)
# 合并两个 DataFrame
df_combined = pd.concat([df_combined, df2], ignore_index=True)

# 查看合并后的结果
print(df_combined)
# Out:
#     category                                           question  \
# 0      event  How many years of Carnegie Mellon University d...
# 1      event  Which organization provides dogs for the Paws ...
# 2      event  Where is the event 'The Art and Science of Raf...
# 3      event  What is the name of the event celebrating 125 ...
# 4      event  Who is the subject of the exhibition at the Hu...
# ..       ...                                                ...
# 116    event  Where and when is the 'Start Making Sense - Ta...
# 117    event  Which event takes place at PPG Paints Arena on...
# 118    event  What event at Mr Small's Fun House starts at 8...
# 119    event  Which hotels are offering special room rates f...
# 120    event  Where will the 'Connecting to Nature Experient...
#
#                                       reference_answer  \
# 0                                            125 years
# 1                     Animal Friend’s Therapet program
# ...

# %%
df_combined.to_csv('1001.csv',index=False)

# %%
list3=[
  {
    "category":"music&art",
    "question": "What are the Heinz Hall Box Office hours for purchasing tickets?",
    "reference_answer": "Monday - Friday, 9 am - 6 PM, Saturday 12 pm - 4 pm",
    "support_context_segment": "The Heinz Hall Box Office hours are Monday - Friday, 9 am - 6 PM, Saturday 12 pm - 4 pm."
  },
  {    "category":"music&art",
    "question": "What is the 'free-flow' screening system at Heinz Hall?",
    "reference_answer": "A system that allows patrons to simply walk through unimpeded without removing coats or bags; cell phones and keys can remain in pockets.",
    "support_context_segment": "Heinz Hall selected a “free-flow” system which allows patrons to simply walk through unimpeded. There is no need to remove coats or bags; cell phones and keys can remain in your pockets."
  },
  {    "category":"music&art",
    "question": "Where can ticket holders find guaranteed prepaid parking near Heinz Hall?",
    "reference_answer": "Sixth & Penn garage across from Heinz Hall",
    "support_context_segment": "Guaranteed prepaid parking is available to all ticket holders in the Sixth & Penn garage across from Heinz Hall."
  },
  {    "category":"music&art",
    "question": "Who is the Principal of the First Violin section in the Pittsburgh Symphony Orchestra?",
    "reference_answer": "David McCarroll",
    "support_context_segment": "David McCarroll | Concertmaster | Rachel Mellon Walton Chair"
  },
  {    "category":"music&art",
    "question": "Who is the Principal of the Flute section?",
    "reference_answer": "Jackman Pfouts",
    "support_context_segment": "Principal | Jackman Pfouts Flute Chair+"
  },

{    "category":"music&art",
"question": "Who is the Music Director of the Pittsburgh Symphony Orchestra for the 2025–2026 season?",
"reference_answer": "Manfred Honeck",
"support_context_segment": ""
},

{    "category":"music&art",
"question": "What is the minimum number of people required to receive a group discount at Heinz Hall?",
"reference_answer": "10",
"support_context_segment": "To receive the group discount, you must have a group of 10 or more for any BNY Classics, PNC Pops, Highmark Holiday Pops, Fiddlesticks Family Concerts or PSO Disrupt performances.*"
},

{    "category":"music&art",
"question": "When is the final payment due for a group order at Heinz Hall?",
"reference_answer": "One month prior to the concert date",
"support_context_segment": "Final payment is due one month prior to the concert date. If the performance is within one month, please contact us for special arrangements."
},
{    "category":"music&art",
"question": "How can you make a group reservation for a Pittsburgh Symphony Orchestra performance?",
"reference_answer": "Call 412.392.4900 or email group_sales@pittsburghsymphony.org",
"support_context_segment": "To order your tickets, please call 412.392.4900 or email group_sales@pittsburghsymphony.org."
},
{    "category":"music&art",
  "question": "Which restaurants offer exclusive subscriber dining discounts for PSO members as of September 2023?",
  "reference_answer": [
    "Fl. 2 at Fairmont Pittsburgh",
    "Braddock’s Rebellion inside the Renaissance Hotel",
    "Vallozzi’s",
    "Sultan Döner Gyro",
    "Space Bar",
    "Redbeard's on Sixth",
    "Talia"
  ],
  "support_context_segment": "",
}
]

# %%
df3=pd.DataFrame(list3)
# 合并两个 DataFrame
df_combined = pd.concat([df_combined, df3], ignore_index=True)

# 查看合并后的结果
print(df_combined)
df_combined.to_csv('1015.csv',index=False)
# Out:
#       category                                           question  \
# 0        event  How many years of Carnegie Mellon University d...
# 1        event  Which organization provides dogs for the Paws ...
# 2        event  Where is the event 'The Art and Science of Raf...
# 3        event  What is the name of the event celebrating 125 ...
# 4        event  Who is the subject of the exhibition at the Hu...
# ..         ...                                                ...
# 126  music&art  Who is the Music Director of the Pittsburgh Sy...
# 127  music&art  What is the minimum number of people required ...
# 128  music&art  When is the final payment due for a group orde...
# 129  music&art  How can you make a group reservation for a Pit...
# 130  music&art  Which restaurants offer exclusive subscriber d...
#
#                                       reference_answer  \
# 0                                            125 years
# 1                     Animal Friend’s Therapet program
# ...

# %%
list4=[{
    "category":"general_info",
"question": "Which colleges and schools are part of Carnegie Mellon University?",
"reference_answer": "College of Engineering, College of Fine Arts, Dietrich College of Humanities & Social Science, Heinz College of Information Systems and Public Policy, Mellon College of Science, School of Computer Science, Tepper School of Business",
"support_context_segment": "Conduct revolutionary research with CMU faculty across our seven colleges and schools. Drive technological and cultural transformation in fields ranging from AI and robotics to the arts and public policy.\n\nCollege of Engineering\nCollege of Fine Arts\nDietrich College of Humanities & Social Science\nHeinz College of Information Systems and Public Policy\nMellon College of Science\nSchool of Computer Science\nTepper School of Business"
},
{ "category":"general_info",
"question": "What benefit does the Arts Pass provide to Carnegie Mellon students?",
"reference_answer": "Free access to renowned museums and attractions with your CMU ID, from the Andy Warhol Museum to the National Aviary",
"support_context_segment": "Arts Pass\nUnlock free access to renowned museums and attractions with your CMU ID, from the Andy Warhol Museum to the National Aviary."
},
{ "category":"general_info",
"question": "Which company provides electricity to Pittsburgh and who founded it?",
"reference_answer": "Duquesne Light, founded by George Westinghouse in 1912",
"support_context_segment": "The city is served by Duquesne Light, one of the original 1912 power companies founded by George Westinghouse."
},
{ "category":"general_info",
"question": "Which organizations provide water service to Pittsburgh?",
"reference_answer": "Pittsburgh Water and Sewer Authority and Pennsylvania American Water",
"support_context_segment": "Water service is provided by the Pittsburgh Water and Sewer Authority and Pennsylvania American Water."
},
{ "category":"general_info",
"question": "What percentage of Pittsburgh's population identified as Protestant in 2014?",
"reference_answer": "42%",
"support_context_segment": "According to a 2014 study by the Pew Research Center, 78% of the population of the city identified themselves as Christians, with 42% professing attendance at a variety of churches that could be considered Protestant, and 32% professing Catholic beliefs."
},
{ "category":"general_info",
"question": "Which professional major league sports teams are based in Pittsburgh?",
"reference_answer": "Pittsburgh Pirates, Pittsburgh Steelers, Pittsburgh Penguins",
"support_context_segment": "",
},
{ "category":"general_info",
"question": "Where does Robert Morris University play its Division I college hockey games?",
"reference_answer": "Island Sports Center",
"support_context_segment": "Robert Morris University fields a Division I college hockey team at the Island Sports Center."
},
{ "category":"general_info",
"question": "What is the local dialect of Pittsburgh commonly called?",
"reference_answer": "Pittsburghese",
"support_context_segment": "The Pittsburgh English dialect, commonly called Pittsburghese, was influenced by Scots-Irish, German, and Eastern European immigrants and African Americans."
},
{ "category":"general_info",
"question": "What factors contributed to the decline of the U.S. steel industry in the 1970s and 1980s?",
"reference_answer": "Increasing foreign competition, inexpensive American mini-mills, recessions, the 1973 oil crisis, and increasing use of other materials",
"support_context_segment": "During the 1970s and 1980s, the U.S. steel industry came under increasing pressure from foreign competition and from American mini-mills constructed inexpensively using salvaged steel. Manufacture in Germany and Japan was booming. Foreign mills and factories, built with the latest technology, benefited from lower labor costs and powerful government-corporate partnerships, allowing them to capture increasing market shares of steel and steel products. Separately, demand for steel softened due to recessions, the 1973 oil crisis, and increasing use of other materials."
},
{
    "category":"general_info",
"question": "What report marked the beginning of the steel industry's decline era in 1974?",
"reference_answer": "\"Building on Basics\" by the RIDC",
"support_context_segment": "The era began with the RIDC's \"Building on Basics\" report in 1974."
}
]

# %%
df4=pd.DataFrame(list4)
# 合并两个 DataFrame
df_combined = pd.concat([df_combined, df4], ignore_index=True)

# 查看合并后的结果
print(df_combined)
df_combined.to_csv('1037.csv',index=False)
# Out:
#          category                                           question  \
# 0           event  How many years of Carnegie Mellon University d...
# 1           event  Which organization provides dogs for the Paws ...
# 2           event  Where is the event 'The Art and Science of Raf...
# 3           event  What is the name of the event celebrating 125 ...
# 4           event  Who is the subject of the exhibition at the Hu...
# ..            ...                                                ...
# 136  general_info  Which professional major league sports teams a...
# 137  general_info  Where does Robert Morris University play its D...
# 138  general_info  What is the local dialect of Pittsburgh common...
# 139  general_info  What factors contributed to the decline of the...
# 140  general_info  What report marked the beginning of the steel ...
#
#                                       reference_answer  \
# 0                                            125 years
# ...

# %%
list5=[{
    "category":"sport",
"question": "What is the seating capacity of PNC Park in Pittsburgh?",
"reference_answer": "38,362",
"support_context_segment": "Capacity: 38,362"
},

{    "category":"sport",
"question": "What is PNC Park known for?",
"reference_answer": "Skyline views, fireworks nights, the Pittsburgh Pierogi Race, fantastic local food and brews",
"support_context_segment": "Known For: Skyline views, fireworks nights, the Pittsburgh Pierogi Race, fantastic local food and brews"
},

{    "category":"sport",
"question": "Which college did Rod Woodson attend?",
"reference_answer": "Purdue",
"support_context_segment": "College | Purdue"
},
{    "category":"sport",
"question": "In what year was Rod Woodson inducted into the Pro Football Hall of Fame?",
"reference_answer": "2009",
"support_context_segment": "Rod Woodson was voted into the Pro Football Hall of Fame as a member of the Class of 2009."
},

{    "category":"sport",
"question": "Which team did the Steelers defeat in their first Super Bowl win?",
"reference_answer": "Minnesota Vikings",
"support_context_segment": "Steelers 16, Minnesota Vikings 6 Tulane Stadium New Orleans, Louisiana January 12, 1975; Attendance: 80,997"
},
{    "category":"sport",
"question": "What is the purpose of the Nike Next Ones program?",
"reference_answer": "Honors the best high school football players from around the country with an invitation to compete in a skills challenge and experience behind-the-scenes action.",
"support_context_segment": "The Nike Next Ones program honors the best high school football players from around the country with an invitation to compete in a skills challenge and experience behind-the-scenes action."
},

{    "category":"sport",
"question": "Which Pittsburgh Penguins player had the most goals in the 22-23 season?",
"reference_answer": "Jake Guentzel (36)",
"support_context_segment": "22-23 | Jake Guentzel (36) | Sidney Crosby (60) | Sidney Crosby (93)"
},

{    "category":"sport",
"question":" Who performed the anthem at the 2025 Black Hockey History Day Game?",
"reference_answer": "Anita Levels",
"support_context_segment":"2025 Black Hockey History Day Game Anthem Performer Anita Levels\n\nAnita is a vocal artist, voice influencer, songwriter and producer who began singing at the age of 3 years old in Frankfurt, West Germany."
},

{    "category":"sport",
    "question":"What is the purpose of the Willie O'Ree Academy announced by the Pittsburgh Penguins?",
    "reference_answer":"To provide unique training, social and mentorship opportunities for Black youth hockey players in the Pittsburgh region.",
    "Support_context_segment:":"The Pittsburgh Penguins today announced the creation of the 'Willie O'Ree Academy,' designed to provide unique training, social and mentorship opportunities for Black youth hockey players in the Pittsburgh region."
},

{    "category":"sport",
    "question":"Where was the screening of 'Beyond Their Years' held?",
    "reference_answer":"Carnegie of Homestead Music Hall in Munhall, PA",
    "Support_context_segment:":"Fans were able to join the Pittsburgh Penguins Foundation, the Carnegie Initiative, and Pittsburgh Hardball Academy for a screening of 'Beyond Their Years: The Incredible Legacies of Herb Carnegie and Buck O'Neilâ at Carnegie of Homestead Music Hall in Munhall, PA."
}]

# %%
df5=pd.DataFrame(list5)
# 合并两个 DataFrame
df_combined = pd.concat([df_combined, df5], ignore_index=True)

# 查看合并后的结果
print(df_combined)
df_combined.to_csv('1055.csv',index=False)
# Out:
#     category                                           question  \
# 0      event  How many years of Carnegie Mellon University d...
# 1      event  Which organization provides dogs for the Paws ...
# 2      event  Where is the event 'The Art and Science of Raf...
# 3      event  What is the name of the event celebrating 125 ...
# 4      event  Who is the subject of the exhibition at the Hu...
# ..       ...                                                ...
# 146    sport  What is the purpose of the Nike Next Ones prog...
# 147    sport  Which Pittsburgh Penguins player had the most ...
# 148    sport   Who performed the anthem at the 2025 Black Ho...
# 149    sport  What is the purpose of the Willie O'Ree Academ...
# 150    sport  Where was the screening of 'Beyond Their Years...
#
#                                       reference_answer  \
# 0                                            125 years
# 1                     Animal Friend’s Therapet program
# ...
